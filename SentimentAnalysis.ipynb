# %%
import nltk
from nltk.corpus import twitter_samples

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to C:\Users\Muneeb
# [nltk_data]     Anwar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\twitter_samples.zip.
# True

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
len(positive_tweets)
# Out:
# 5000

# %%
len(negative_tweets)
# Out:
# 5000

# %%
# text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
tokens
# Out:
# [['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@Lamb2ja',
#   'Hey',
#   'James',
#   '!',
#   'How',
#   'odd',
#   ':/',
#   'Please',
#   'call',
#   'our',
#   'Contact',
#   'Centre',
#   'on',
#   '02392441234',
#   'and',
#   'we',
#   'will',
#   'be',
#   'able',
#   'to',
#   'assist',
#   'you',
#   ':)',
#   'Many',
#   'thanks',
#   '!'],
#  ['@DespiteOfficial',
#   'we',
#   'had',
#   'a',
#   'listen',
#   'last',
#   'night',
#   ':)',
#   'As',
#   'You',
#   'Bleed',
#   'is',
#   'an',
#   'amazing',
#   'track',
#   '.',
#   'When',
#   'are',
#   'you',
#   'in',
#   'Scotland',
#   '?',
#   '!'],
#  ['@97sides', 'CONGRATS', ':)'],
#  ['yeaaaah',
#   'yippppy',
#   '!',
#   '!',
#   '!',
#   'my',
#   'accnt',
#   'verified',
#   'rqst',
#   'has',
#   'succeed',
#   'got',
#   'a',
# ...

# %%
tokens[100]
# Out:
# ['@metalgear_jp',
#  '@Kojima_Hideo',
#  'I',
#  'want',
#  "you're",
#  'T-shirts',
#  '!',
#  'They',
#  'are',
#  'so',
#  'cool',
#  '!',
#  ':D']

# %% [markdown]
# ### POS Tagging

# %%
from nltk.tag import pos_tag

# %%
pos_tag(tokens[300])
# Out:
# [('Stats', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('day', 'NN'),
#  ('have', 'VBP'),
#  ('arrived', 'VBN'),
#  ('.', '.'),
#  ('2', 'CD'),
#  ('new', 'JJ'),
#  ('followers', 'NNS'),
#  ('and', 'CC'),
#  ('NO', 'NNP'),
#  ('unfollowers', 'NNS'),
#  (':)', 'VBP'),
#  ('via', 'IN'),
#  ('http://t.co/xxlXs6xYwe', 'NN'),
#  ('.', '.')]

# %%
from nltk

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Muneeb Anwar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize('followers')
# Out:
# 'follower'

# %%
lemmatizer.lemmatize("stripes", 'v')
# Out:
# 'strip'

# %%
lemmatizer.lemmatize("stripes", 'n')
# Out:
# 'stripe'

# %% [markdown]
# ### Stop Words

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
from nltk.stem.wordnet import WordNetLemmatizer

def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

# %%
tokens[600]
# Out:
# ['Hi',
#  '@NJES44',
#  ',',
#  'thanks',
#  'for',
#  'connecting',
#  '.',
#  'We',
#  'specialise',
#  'in',
#  'thermal',
#  'imaging',
#  'surveys',
#  '–',
#  'here',
#  'if',
#  'you',
#  'need',
#  'us',
#  ':)']

# %%
lemmatize_sentence(tokens[600])
# Out:
# ['Hi',
#  '@NJES44',
#  ',',
#  'thanks',
#  'for',
#  'connect',
#  '.',
#  'We',
#  'specialise',
#  'in',
#  'thermal',
#  'image',
#  'survey',
#  '–',
#  'here',
#  'if',
#  'you',
#  'need',
#  'us',
#  ':)']

# %%
import re, string

def remove_noise(tokens, stop_words):

    cleaned_tokens = []

    for token, tag in pos_tag(tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]'\
                       '|(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
remove_noise(tokens[100], stop_words)
# Out:
# ['want', 't-shirts', 'cool', ':d']

# %% [markdown]
# #### Apply to all tweets

# %%
positive_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
positive_tokens
# Out:
# [['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@Lamb2ja',
#   'Hey',
#   'James',
#   '!',
#   'How',
#   'odd',
#   ':/',
#   'Please',
#   'call',
#   'our',
#   'Contact',
#   'Centre',
#   'on',
#   '02392441234',
#   'and',
#   'we',
#   'will',
#   'be',
#   'able',
#   'to',
#   'assist',
#   'you',
#   ':)',
#   'Many',
#   'thanks',
#   '!'],
#  ['@DespiteOfficial',
#   'we',
#   'had',
#   'a',
#   'listen',
#   'last',
#   'night',
#   ':)',
#   'As',
#   'You',
#   'Bleed',
#   'is',
#   'an',
#   'amazing',
#   'track',
#   '.',
#   'When',
#   'are',
#   'you',
#   'in',
#   'Scotland',
#   '?',
#   '!'],
#  ['@97sides', 'CONGRATS', ':)'],
#  ['yeaaaah',
#   'yippppy',
#   '!',
#   '!',
#   '!',
#   'my',
#   'accnt',
#   'verified',
#   'rqst',
#   'has',
#   'succeed',
#   'got',
#   'a',
# ...

# %%
positive_clean = []

# %%
for tokens in positive_tokens:
    positive_clean.append(remove_noise(tokens, stop_words))

# %%
positive_clean
# Out:
# [['#followfriday', 'top', 'engage', 'member', 'community', 'week', ':)'],
#  ['hey',
#   'james',
#   'odd',
#   ':/',
#   'please',
#   'call',
#   'contact',
#   'centre',
#   '02392441234',
#   'able',
#   'assist',
#   ':)',
#   'many',
#   'thanks'],
#  ['listen', 'last', 'night', ':)', 'bleed', 'amazing', 'track', 'scotland'],
#  ['congrats', ':)'],
#  ['yeaaaah',
#   'yippppy',
#   'accnt',
#   'verify',
#   'rqst',
#   'succeed',
#   'get',
#   'blue',
#   'tick',
#   'mark',
#   'fb',
#   'profile',
#   ':)',
#   '15',
#   'day'],
#  ['one', 'irresistible', ':)', '#flipkartfashionfriday'],
#  ['like',
#   'keep',
#   'lovely',
#   'customer',
#   'wait',
#   'long',
#   'hope',
#   'enjoy',
#   'happy',
#   'friday',
#   'lwwf',
#   ':)'],
#  ['second',
#   'thought',
#   '’',
#   'enough',
#   'time',
#   'dd',
#   ':)',
#   'new',
#   'short',
#   'enter',
#   'system',
#   'sheep',
#   'must',
#   'buy'],
#  ['jgh', 'go', 'bayan', ':d', 'bye'],
#  ['act',
# ...

# %%
negative_tokens = twitter_samples.tokenized('negative_tweets.json')

# %%
# negative_tokens

# %%
negative_clean = []

# %%
for tokens in negative_tokens:
    negative_clean.append(remove_noise(tokens, stop_words))

# %%
negative_clean
# Out:
# [['hopeless', 'tmr', ':('],
#  ['everything',
#   'kid',
#   'section',
#   'ikea',
#   'cute',
#   'shame',
#   "i'm",
#   'nearly',
#   '19',
#   '2',
#   'month',
#   ':('],
#  ['heart', 'slide', 'waste', 'basket', ':('],
#  ['“', 'hate', 'japanese', 'call', 'ban', ':(', ':(', '”'],
#  ['dang', 'start', 'next', 'week', 'work', ':('],
#  ['oh', 'god', 'baby', 'face', ':('],
#  ['make', 'smile', ':('],
#  ['work',
#   'neighbour',
#   'motor',
#   'asked',
#   'say',
#   'hat',
#   'update',
#   'search',
#   ':('],
#  [':(', 'sialan', ':('],
#  ['athabasca',
#   'glacier',
#   '#1948',
#   ':-(',
#   '#athabasca',
#   '#glacier',
#   '#jasper',
#   '#jaspernationalpark',
#   '#alberta',
#   '#explorealberta',
#   '…'],
#  ['really', 'good', 'g', 'idea', "i'm", 'never', 'go', 'meet', ':('],
#  ['mare', 'ivan', ':('],
#  ['happy', 'trip', 'keep', 'safe', 'see', 'soon', ':('],
#  ["i'm", 'tire', 'hahahah', ':('],
#  ['knee', 'replacement', 'get', 'day', ':-(', 'ouch'],
#  ['relate',
# ...

# %%
negative_tokens[80]
# Out:
# ['I', 'MISS', 'INFINITE', ':-(']

# %%
dict([token, True] for token in ['I', 'MISS', 'INFINITE', ':-('])
# Out:
# {'I': True, 'MISS': True, 'INFINITE': True, ':-(': True}

# %%
def get_tweets_for_model(cleaned_tokens_list):
    return_list = []
    for tweet_tokens in cleaned_tokens_list:
        return_list.append(dict([token, ''] for token in tweet_tokens))
    return return_list  

positive_tokens_train = get_tweets_for_model(positive_tokens)
negative_tokens_train = get_tweets_for_model(negative_tokens)

# %%
positive_tokens
# Out:
# [['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['@Lamb2ja',
#   'Hey',
#   'James',
#   '!',
#   'How',
#   'odd',
#   ':/',
#   'Please',
#   'call',
#   'our',
#   'Contact',
#   'Centre',
#   'on',
#   '02392441234',
#   'and',
#   'we',
#   'will',
#   'be',
#   'able',
#   'to',
#   'assist',
#   'you',
#   ':)',
#   'Many',
#   'thanks',
#   '!'],
#  ['@DespiteOfficial',
#   'we',
#   'had',
#   'a',
#   'listen',
#   'last',
#   'night',
#   ':)',
#   'As',
#   'You',
#   'Bleed',
#   'is',
#   'an',
#   'amazing',
#   'track',
#   '.',
#   'When',
#   'are',
#   'you',
#   'in',
#   'Scotland',
#   '?',
#   '!'],
#  ['@97sides', 'CONGRATS', ':)'],
#  ['yeaaaah',
#   'yippppy',
#   '!',
#   '!',
#   '!',
#   'my',
#   'accnt',
#   'verified',
#   'rqst',
#   'has',
#   'succeed',
#   'got',
#   'a',
# ...

# %%
positive_tokens_train
# Out:
# [{'#FollowFriday': '',
#   '@France_Inte': '',
#   '@PKuchly57': '',
#   '@Milipol_Paris': '',
#   'for': '',
#   'being': '',
#   'top': '',
#   'engaged': '',
#   'members': '',
#   'in': '',
#   'my': '',
#   'community': '',
#   'this': '',
#   'week': '',
#   ':)': ''},
#  {'@Lamb2ja': '',
#   'Hey': '',
#   'James': '',
#   '!': '',
#   'How': '',
#   'odd': '',
#   ':/': '',
#   'Please': '',
#   'call': '',
#   'our': '',
#   'Contact': '',
#   'Centre': '',
#   'on': '',
#   '02392441234': '',
#   'and': '',
#   'we': '',
#   'will': '',
#   'be': '',
#   'able': '',
#   'to': '',
#   'assist': '',
#   'you': '',
#   ':)': '',
#   'Many': '',
#   'thanks': ''},
#  {'@DespiteOfficial': '',
#   'we': '',
#   'had': '',
#   'a': '',
#   'listen': '',
#   'last': '',
#   'night': '',
#   ':)': '',
#   'As': '',
#   'You': '',
#   'Bleed': '',
#   'is': '',
#   'an': '',
#   'amazing': '',
#   'track': '',
#   '.': '',
#   'When': '',
#   'are': '',
#   'you': '',
#   'in': '',
# ...

# %%
import random

positive_dataset = [(tweet_dict, "Positive") for tweet_dict in positive_tokens_train]

negative_dataset = [(tweet_dict, "Negative") for tweet_dict in negative_tokens_train]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

# %%
dataset
# Out:
# [({'i': True,
#    'cant': True,
#    'watch': True,
#    'hxh': True,
#    'in': True,
#    'this': True,
#    'place': True,
#    'besides': True,
#    'youtube': True,
#    'vids': True,
#    'like': True,
#    "'": True,
#    'top': True,
#    '10': True,
#    'badass': True,
#    'killua': True,
#    'scenes': True,
#    ':)': True,
#    'im': True,
#    'suffering': True},
#   'Positive'),
#  ({'एक': True,
#    'बार': True,
#    'फिर': True,
#    'सेँ': True,
#    'धोखा': True,
#    '...': True,
#    '>:(': True,
#    '>': True,
#    '_': True,
#    '<': True,
#    '—': True,
#    'feeling': True,
#    'silly': True,
#    'at': True,
#    'Chandauli': True,
#    'Majhwar': True,
#    'railway': True,
#    'station': True,
#    'http://t.co/iWAeDmuooP': True},
#   'Negative'),
#  ({'@The_Sleigher': True,
#    'among': True,
#    'my': True,
#    'all': True,
#    'time': True,
#    'fav': True,
#    'tweets': True,
#    ':D': True},
#   'Positive'),
# ...

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.9953333333333333
# Most Informative Features
#                       :( = True           Negati : Positi =   2055.4 : 1.0
#                       :) = True           Positi : Negati =    992.4 : 1.0
#                     miss = True           Negati : Positi =     23.8 : 1.0
#                      sad = True           Negati : Positi =     22.6 : 1.0
#                     THAT = True           Negati : Positi =     21.5 : 1.0
#                    tired = True           Negati : Positi =     20.2 : 1.0
#                  arrived = True           Positi : Negati =     18.3 : 1.0
#                   Thanks = True           Positi : Negati =     17.2 : 1.0
#                    Thank = True           Positi : Negati =     16.9 : 1.0
#                    Enjoy = True           Positi : Negati =     16.4 : 1.0
# None
